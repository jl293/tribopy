# %%
import tkinter
tkinter.TkVersion
# Out:
# 8.6

# %%
from main import *

LubricationConformalContacts.ReynoldsIntegrated(1, 2, 3, 4, 0.5, 6)

# %% [markdown]
# # Working through differential equations

# %% [markdown]
# ### Equation 8.1 from page 116

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Constants
U = 1.0  # Example constant for U
n = 1.0  # Example constant for n

# Define the system of ODEs
def system(x, y):
    h, p, dhdx, dpdx = y  # Unpack the state vector
    d2hdx2 = (6 * U * n * dhdx) / (h**3)  # From the original equation
    d2pdx2 = (6 * U * n * dhdx) / h**3  # Rearranged from the original equation
    return [dhdx, dpdx, d2hdx2, d2pdx2]

# Define the spatial domain
x_span = (0, 10)  # From 0 to 10
x_eval = np.linspace(x_span[0], x_span[1], 100)  # Points to evaluate

# Initial conditions: h(0), p(0), dh/dx(0), dp/dx(0)
initial_conditions = [1, 0, 0, 0]  # Example initial conditions

# Solve the system of ODEs
solution = solve_ivp(system, x_span, initial_conditions, t_eval=x_eval)

# Extract results
h_solution = solution.y[0]
p_solution = solution.y[1]

# Plot the results
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(solution.t, h_solution, label='h(x)', color='blue')
plt.title('Solution of the differential equations')
plt.ylabel('h(x)')
plt.grid()
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(solution.t, p_solution, label='p(x)', color='orange')
plt.xlabel('x')
plt.ylabel('p(x)')
plt.grid()
plt.legend()

plt.tight_layout()
plt.show()
